# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/slugg/Documents/GitHub/three_idiot/전처리_데이터/vacuum.csv', header=None,index_col=None)
data
# Out:
#                                                         0  1  \
# 0                           저스트원 무선 진공청소기, 화이트, SN-XR330V  5
# 1                            저스트원 무선 진공청소기, 핑크, SN-XR330V  5
# 2                            저스트원 무선 진공청소기, 핑크, SN-XR330V  5
# 3                           저스트원 무선 진공청소기, 화이트, SN-XR330V  5
# 4                           저스트원 무선 진공청소기, 화이트, SN-XR330V  5
# ...                                                   ... ..
# 167279  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
# 167280  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
# 167281  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
# 167282  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  4
# 167283  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
#
#                                                         2  \
# 0       가성비 미쳤다잉?! 전에 쓰던거 보다 소음이 작은 것 같아요1단은 힘이 없어서 안쓸...
# 1       귀엽고 가벼운 청소기 추천 ! Q. 가성비 좋은 청소기 찾으세요?Q. 가볍고 보관이...
# ...

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                                                         0  1  \
# 0                           저스트원 무선 진공청소기, 화이트, SN-XR330V  5
# 1                            저스트원 무선 진공청소기, 핑크, SN-XR330V  5
# 2                            저스트원 무선 진공청소기, 핑크, SN-XR330V  5
# 3                           저스트원 무선 진공청소기, 화이트, SN-XR330V  5
# 4                           저스트원 무선 진공청소기, 화이트, SN-XR330V  5
# ...                                                   ... ..
# 166297  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
# 166298  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  3
# 166299  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
# 166300  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
# 166301  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
#
#                                                         2  \
# 0       가성비 미쳤다잉?! 전에 쓰던거 보다 소음이 작은 것 같아요1단은 힘이 없어서 안쓸...
# 1       귀엽고 가벼운 청소기 추천 ! Q. 가성비 좋은 청소기 찾으세요?Q. 가볍고 보관이...
# ...

# %%
data.drop(data[data.columns[3:5]], inplace=True, axis=1)
data
# Out:
#                                                         0  1  \
# 0                           저스트원 무선 진공청소기, 화이트, SN-XR330V  5
# 1                            저스트원 무선 진공청소기, 핑크, SN-XR330V  5
# 2                            저스트원 무선 진공청소기, 핑크, SN-XR330V  5
# 3                           저스트원 무선 진공청소기, 화이트, SN-XR330V  5
# 4                           저스트원 무선 진공청소기, 화이트, SN-XR330V  5
# ...                                                   ... ..
# 166297  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
# 166298  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  3
# 166299  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
# 166300  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
# 166301  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
#
#                                                         2
# 0       가성비 미쳤다잉?! 전에 쓰던거 보다 소음이 작은 것 같아요1단은 힘이 없어서 안쓸...
# 1       귀엽고 가벼운 청소기 추천 ! Q. 가성비 좋은 청소기 찾으세요?Q. 가볍고 보관이...
# ...

# %%
data.reset_index(drop=True)
# Out:
#                                                        0  1  \
# 0                          저스트원 무선 진공청소기, 화이트, SN-XR330V  5
# 1                           저스트원 무선 진공청소기, 핑크, SN-XR330V  5
# 2                           저스트원 무선 진공청소기, 핑크, SN-XR330V  5
# 3                          저스트원 무선 진공청소기, 화이트, SN-XR330V  5
# 4                          저스트원 무선 진공청소기, 화이트, SN-XR330V  5
# ...                                                  ... ..
# 94094  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
# 94095  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  3
# 94096  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
# 94097  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
# 94098  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...  5
#
#                                                        2
# 0      가성비 미쳤다잉?! 전에 쓰던거 보다 소음이 작은 것 같아요1단은 힘이 없어서 안쓸...
# 1      귀엽고 가벼운 청소기 추천 ! Q. 가성비 좋은 청소기 찾으세요?Q. 가볍고 보관이...
# 2      가성비 좋은 넘 예쁜 핑크색 청소기 +두달 사용후기 추가했어요장점1. 디자인이나 색...
# ...

# %%
data.iloc[:, 1:2] = data.iloc[:, 1:2].astype(int)

# %%
data = data.rename(columns={0: '제품명', 1: '별점', 2: '리뷰'})

# %%
data = data[(data['별점'] > 4) | (data['별점'] < 3)]

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.to_csv('C:/Users/slugg/Documents/GitHub/three_idiot/전처리_데이터/제품명_별점_리뷰(청소기).csv')

# %%
good = data[data['별점']==5]
bad = data[data['별점'] < 3]
bad
# Out:
#                                                      제품명  별점  \
# 13                          저스트원 무선 진공청소기, 핑크, SN-XR330V   1
# 32                          저스트원 무선 진공청소기, 민트, SN-XR330V   2
# 40                          저스트원 무선 진공청소기, 블랙, SN-XR330V   1
# 62                         저스트원 무선 진공청소기, 화이트, SN-XR330V   2
# 70                          저스트원 무선 진공청소기, 민트, SN-XR330V   2
# ...                                                  ...  ..
# 74221  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...   2
# 74390  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...   2
# 74418  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...   2
# 74443  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...   1
# 74447  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...   1
#
#                                                       리뷰
# 13     3달만에 고장.. 3달 쓴 후기입니다. 유선청소기를 선호하는편이라 메인청소기는 창고...
# 32     내돈내산 후기요~ 집에서 쓰던 청소기가 고장나서 무선으로 찾다가 디자인도 색상도 이...
# 40     제품의 부품이 도착하지 않았습니다. 왜 이 메인 작품은 상자 안에 없나요? 작은 노...
# ...

# %%
def labeling(d):
    if d == 5:
        return 1
    else:
        return 0

# %%
data['긍정/부정'] = data.별점.apply(labeling)
data
# Out:
#                                                      제품명  별점  \
# 0                          저스트원 무선 진공청소기, 화이트, SN-XR330V   5
# 1                           저스트원 무선 진공청소기, 핑크, SN-XR330V   5
# 2                           저스트원 무선 진공청소기, 핑크, SN-XR330V   5
# 3                          저스트원 무선 진공청소기, 화이트, SN-XR330V   5
# 4                          저스트원 무선 진공청소기, 화이트, SN-XR330V   5
# ...                                                  ...  ..
# 74480  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...   5
# 74481  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...   5
# 74482  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...   5
# 74483  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...   5
# 74484  휴스톰 HS-8000/HS-9000/HS-10000/HS-11000 전용 극세사 청...   5
#
#                                                       리뷰  긍정/부정
# 0      가성비 미쳤다잉?! 전에 쓰던거 보다 소음이 작은 것 같아요1단은 힘이 없어서 안쓸...      1
# 1      귀엽고 가벼운 청소기 추천 ! Q. 가성비 좋은 청소기 찾으세요?Q. 가볍고 보관이...      1
# ...

# %%
data.iloc[:, 2:4].to_csv('C:/Users/slugg/Documents/GitHub/three_idiot/전처리_데이터/긍정_부정(청소기).csv')
